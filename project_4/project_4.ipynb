# %% [markdown]
# #Project 4

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# import modules and data

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-le'
                   'arning-databases/mushroom/agaricus-lepiota.data', 
                   sep=',', header=None, usecols=[0,1,5], names=['edible','shape','odor'])

# %%
data.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>edible</th>
#       <th>shape</th>
#       <th>odor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>p</td>
#       <td>x</td>
#       <td>p</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>e</td>
#       <td>x</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>e</td>
#       <td>b</td>
#       <td>l</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>p</td>
#       <td>x</td>
#       <td>p</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>e</td>
#       <td>x</td>
#       <td>n</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# now we must replace the data with numbers

# %%
data.replace(to_replace={"edible":{'p': 1, 'e': 0}}, inplace=True)
data.replace(to_replace={'odor':{'a':0, 'l':1, 'c':2, 'y':3, 'f':4, 'm':5, 'n':6, 'p':7, 's':8}}, inplace=True)
data.replace(to_replace={'shape':{'b':0, 'c':1, 'x':2, 'f':3, 'k':4, 's':5}}, inplace=True)

# %%
data.tail()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>edible</th>
#       <th>shape</th>
#       <th>odor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8119</th>
#       <td>0</td>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>8120</th>
#       <td>0</td>
#       <td>2</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>8121</th>
#       <td>0</td>
#       <td>3</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>8122</th>
#       <td>1</td>
#       <td>4</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>8123</th>
#       <td>0</td>
#       <td>2</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# now we can graph the actual data

# %%
sns.set(style="ticks", context="talk")
pal = sns.cubehelix_palette(4, 1.5, .75, light=.6, dark=.2)
g = sns.lmplot(x='odor', y='shape',data=data, palette=pal, size=7)
g.set_axis_labels("odor", "shape")

# %% [markdown]
# now we have to create two new data frames from the columnns pandas using get_dummies

# %%
df1 = pd.get_dummies(pd.Series(data['odor']))
df2 = pd.get_dummies(pd.Series(data['shape']))

# %%
df1.apply(pd.value_counts)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7724</td>
#       <td>7724</td>
#       <td>7932</td>
#       <td>7548</td>
#       <td>5964</td>
#       <td>8088</td>
#       <td>4596</td>
#       <td>7868</td>
#       <td>7548</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>400</td>
#       <td>400</td>
#       <td>192</td>
#       <td>576</td>
#       <td>2160</td>
#       <td>36</td>
#       <td>3528</td>
#       <td>256</td>
#       <td>576</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2.apply(pd.value_counts)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7672</td>
#       <td>8120</td>
#       <td>4468</td>
#       <td>4972</td>
#       <td>7296</td>
#       <td>8092</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>452</td>
#       <td>4</td>
#       <td>3656</td>
#       <td>3152</td>
#       <td>828</td>
#       <td>32</td>
#     </tr>
#   </tbody>
# </table>
# </div>
